# %%
import pandas  as pd
from sklearn.utils import shuffile
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-38-dc826991e325> in <module>
#       1 import pandas  as pd
# ----> 2 from sklearn.utils import shuffile
#
# ImportError: cannot import name 'shuffile' from 'sklearn.utils' (D:\Anaconda3\lib\site-packages\sklearn\utils\__init__.py)

# %%
xlsx_filePath = 'D:/traindata/Clinical data list_OPC (606) v3.xlsx'

# %%
data_1 = pd.read_excel(xlsx_filePath)

# %%
rows,cols = data_1.shape

# %%
print(rows,cols)
# Out:
# 607 34

# %%
data_1.head(10)
# Out:
#                                      Trial PatientID Age at diagnosis  \
# 0  Generated research ID for a participant in thi...         In years
# 1                                          OPC-00001            62.57
# 2                                          OPC-00002            59.75
# 3                                          OPC-00003            60.96
# 4                                          OPC-00004            59.73
# 5                                          OPC-00005            68.72
# 6                                          OPC-00006            54.38
# 7                                          OPC-00007            57.07
# 8                                          OPC-00008            63.54
# 9                                          OPC-00009            63.59
#
#                         Sex  \
# 0  Refers to Sex not Gender
# 1                    Female
# 2                    Female
# 3                      Male
# 4                      Male
# ...

# %%
print(data_1.columns)
# Out:
# Index(['Trial PatientID', 'Age at diagnosis', 'Sex',
#        'ECOG Performance Status Scale', 'Smoking PY', 'Smoking Hx',
#        'Drinking hx', 'Ds Site', 'Subsite', 'T', 'N', 'M ',
#        'Stage\n(AJCC 7th Edition)', 'Path', 'HPV_p16 status (IHC)',
#        'Primary Treatment', 'Chemotherapy ',
#        'Time interval from the date of diagnosis to the RT start date (days)',
#        'Time interval from the date of diagnosis to the RT end date (days)',
#        'Dose (gy)', 'Number of fractions', 'RT Tech',
#        'Time interval from the date of diagnosis to the date of last FU  (days)',
#        'Status', 'Cause of Death', 'Local Failure',
#        'Time interval from the date of diagnosis to the date of  local failure (days)',
#        'Regional Failure',
#        'Time interval from the date of diagnosis to the date of  regional failure (days)',
#        'Distant Failure',
#        'Time interval from the date of diagnosis to the date of  distant failure (days)',
# ...

# %%
data_1.insert(0, 'aa', ['fuck']*rows)

# %%
data_1.head()
# Out:
#      aa                                    Trial PatientID Age at diagnosis  \
# 0  fuck  Generated research ID for a participant in thi...         In years
# 1  fuck                                          OPC-00001            62.57
# 2  fuck                                          OPC-00002            59.75
# 3  fuck                                          OPC-00003            60.96
# 4  fuck                                          OPC-00004            59.73
#
#                         Sex  \
# 0  Refers to Sex not Gender
# 1                    Female
# 2                    Female
# 3                      Male
# 4                      Male
#
#                        ECOG Performance Status Scale  \
# 0  https://ecog-acrin.org/resources/ecog-performa...
# 1                                             ECOG 0
# 2                                             ECOG 0
# 3                                             ECOG 0
# 4                                             ECOG 0
#
# ...

# %%
print(data_1['aa'])
# Out:
# 0      fuck
# 1      fuck
# 2      fuck
# 3      fuck
# 4      fuck
#        ...
# 602    fuck
# 603    fuck
# 604    fuck
# 605    fuck
# 606    fuck
# Name: aa, Length: 607, dtype: object

# %%
data_1['aa'] = [0]*rows

# %%
data_1['aa']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 602    0
# 603    0
# 604    0
# 605    0
# 606    0
# Name: aa, Length: 607, dtype: int64

# %%
data_1.head()
# Out:
#    aa                                    Trial PatientID Age at diagnosis  \
# 0   0  Generated research ID for a participant in thi...         In years
# 1   0                                          OPC-00001            62.57
# 2   0                                          OPC-00002            59.75
# 3   0                                          OPC-00003            60.96
# 4   0                                          OPC-00004            59.73
#
#                         Sex  \
# 0  Refers to Sex not Gender
# 1                    Female
# 2                    Female
# 3                      Male
# 4                      Male
#
#                        ECOG Performance Status Scale  \
# 0  https://ecog-acrin.org/resources/ecog-performa...
# 1                                             ECOG 0
# 2                                             ECOG 0
# 3                                             ECOG 0
# 4                                             ECOG 0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-36-0d429f9ffa75> in <module>
# ----> 1 from sklearn.utils import shuffile
#
# ImportError: cannot import name 'shuffile' from 'sklearn.utils' (D:\Anaconda3\lib\site-packages\sklearn\utils\__init__.py)

# %%
data_1 = shudata_1
